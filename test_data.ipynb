# %%
import numpy as np
import matplotlib.pyplot as plt
import torch  as th
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pickle
import pandas as pd
import seaborn as sns
import random
from tqdm import tqdm
from transformers import AutoModel, AutoConfig
from torch.utils.data import TensorDataset, DataLoader, random_split
from BESTRq_classes.BESTRq import BestRqFramework, RandomProjectionQuantizer
from compute_fft import compute_spectrogram, plot_spectrogram, mask_and_replace
from models.CNN_BiLSTM_Attention import ParallelModel

# %%
filepath = '/Users/martinblot/Downloads/sleep-edf-prepared/cassette-th-data.pck'
xtrain, xvalid, ytrain, yvalid = np.load(filepath, allow_pickle = True)
input_dim = xtrain[0].shape  
input_dim
# Out:
# torch.Size([600, 2])

# %%
xtrain.shape  #nombre de patients / frames
# Out:
# torch.Size([175995, 600, 2])

# %%
numero_analyse=3

plt.figure()
plt.plot(xtrain[numero_analyse,:,0])
plt.plot(xtrain[numero_analyse,:,1])
plt.show()
